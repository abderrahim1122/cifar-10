# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Load the Drive helper and mount
from google.colab import drive
from google.colab import files

# This will prompt for authorization.
drive.mount('/content/drive')

from tqdm import tqdm
tqdm.pandas()
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_label_names():
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
data_dir = "drive/My Drive/Colab Notebooks/cnn_cifar10/"

# %%
def load_dataset_batch(dir_path, batch_id):
    with open(dir_path + '/data_batch_' + str(batch_id), mode='rb') as file:
        # note the encoding type is 'latin1'
        batch = pickle.load(file, encoding='latin1')
        
    features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    labels = batch['labels']
        
    return features, labels

# %%
def display_stats(dir_path, batch_id, sample_id):
    features, labels = load_dataset_batch(dir_path, batch_id)
    
    if not (0 <= sample_id < len(features)):
        print('{} samples in batch {}.  {} is out of range.'.format(len(features), batch_id, sample_id))
        return None

    print('\nStats of batch #{}:'.format(batch_id))
    print('# of Samples: {}\n'.format(len(features)))
    
    label_names = load_label_names()
    label_counts = dict(zip(*np.unique(labels, return_counts=True)))
    for key, value in label_counts.items():
        print('Label Counts of [{}]({}) : {}'.format(key, label_names[key].upper(), value))
    
    sample_image = features[sample_id]
    sample_label = labels[sample_id]
    
    print('\nExample of Image {}:'.format(sample_id))
    print('Image - Min Value: {} Max Value: {}'.format(sample_image.min(), sample_image.max()))
    print('Image - Shape: {}'.format(sample_image.shape))
    print('Label - Label Id: {} Name: {}'.format(sample_label, label_names[sample_label]))
    
    plt.imshow(sample_image)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 8888
display_stats(data_dir, batch_id, sample_id)
# Out:
# Stats of batch #3:
# # of Samples: 10000
#
# Label Counts of [0](AIRPLANE) : 994
# Label Counts of [1](AUTOMOBILE) : 1042
# Label Counts of [2](BIRD) : 965
# Label Counts of [3](CAT) : 997
# Label Counts of [4](DEER) : 990
# Label Counts of [5](DOG) : 1029
# Label Counts of [6](FROG) : 978
# Label Counts of [7](HORSE) : 1015
# Label Counts of [8](SHIP) : 961
# Label Counts of [9](TRUCK) : 1029
#
# Example of Image 8888:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %%
def normalize(x): # Min-Max Scaler
    """
        argument
            - x: input image data in numpy array [32, 32, 3]
        return
            - normalized x 
    """
    min_val = np.min(x)
    max_val = np.max(x)
    x = (x-min_val) / (max_val-min_val)
    return x

# %%
def one_hot_encode(x):
    """
        argument
            - x: a list of labels
        return
            - one hot encoding matrix (number of labels, number of class)
    """
    encoded = np.zeros((len(x), 10))
    
    for idx, val in enumerate(x):
        encoded[idx][val] = 1
    
    return encoded

# %%
def _preprocess_and_save(normalize, one_hot_encode, features, labels, filename):
    features = normalize(features)
    labels = one_hot_encode(labels)

    pickle.dump((features, labels), open(filename, 'wb'))

# %%
def preprocess_and_save_data(dir_path, normalize, one_hot_encode):
    n_batches = 5
    valid_features = []
    valid_labels = []

    for batch_i in range(1, n_batches + 1):
        features, labels = load_dataset_batch(dir_path, batch_i)
        
        # find index to be the point as validation data in the whole dataset of the batch (10%)
        index_of_validation = int(len(features) * 0.1)

        # preprocess the 90% of the whole dataset of the batch
        # - normalize the features
        # - one_hot_encode the labels
        # - save in a new file named, "preprocess_batch_" + batch_number
        # - each file for each batch
        _preprocess_and_save(normalize, one_hot_encode,
                             features[:-index_of_validation], labels[:-index_of_validation], data_dir+ 
                             'preprocess_batch_' + str(batch_i) + '.p')

        # unlike the training dataset, validation dataset will be added through all batch dataset
        # - take 10% of the whold dataset of the batch
        # - add them into a list of
        #   - valid_features
        #   - valid_labels
        valid_features.extend(features[-index_of_validation:])
        valid_labels.extend(labels[-index_of_validation:])

        
    # preprocess the all stacked validation dataset
    _preprocess_and_save(normalize, one_hot_encode,
                         np.array(valid_features), np.array(valid_labels), data_dir+
                         'preprocess_validation.p')

    # load the test dataset
    with open(dir_path + '/test_batch', mode='rb') as file:
        batch = pickle.load(file, encoding='latin1')
# preprocess the testing data
    test_features = batch['data'].reshape((len(batch['data']), 3, 32, 32)).transpose(0, 2, 3, 1)
    test_labels = batch['labels']

    # Preprocess and Save all testing data
    _preprocess_and_save(normalize, one_hot_encode,
                         np.array(test_features), np.array(test_labels), data_dir+
                         'preprocess_testing.p')

# %%
# DO Data Preprocessing and Save it
preprocess_and_save_data(data_dir, normalize, one_hot_encode)

# %%
valid_features, valid_labels = pickle.load(open(data_dir+'preprocess_validation.p', mode='rb'))

# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = tf.placeholder(tf.float32, shape=(None, 32, 32, 3), name='input_x')
y =  tf.placeholder(tf.float32, shape=(None, 10), name='output_y')
keep_prob = tf.placeholder(tf.float32, name='keep_prob')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2021-12-13 23:15:20,125 : WARNING : From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/compat.py:175: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# !pip install tensorflow==1.13.2
# Out:
# Requirement already satisfied: tensorflow==1.13.2 in /usr/local/lib/python3.7/dist-packages (1.13.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (3.17.3)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.37.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.0.8)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.42.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.4.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.19.5)
# Requirement already satisfied: tensorboard<1.14.0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.13.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<1.14.0rc0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.13.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.12.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.10.0.2)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow==1.13.2) (4.0.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.13.2) (1.5.2)

# %%
import tensorflow as tf

# %%
from tensorflow.contrib.layers import flatten


def LeNet(x):    
    
    mu = 0
    sigma = 0.1
    
    # Filter = [filter_height, filter_width, in_channels, out_channels]
    conv1_filter = tf.Variable(tf.truncated_normal(shape = [5,5,3,6],mean = mu, stddev = sigma))
    conv2_filter = tf.Variable(tf.truncated_normal(shape = [5,5,6,16], mean = mu, stddev = sigma))
    
    # TODO: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    conv1 = tf.nn.conv2d(x, conv1_filter, strides = [1,1,1,1], padding = 'VALID')
    # TODO: Activation.
    conv1 = tf.nn.relu(conv1)
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    pool_1 = tf.nn.avg_pool(conv1, ksize = [1,2,2,1], strides = [1,2,2,1], padding = 'VALID')
    
    
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    conv2 = tf.nn.conv2d(pool_1, conv2_filter, strides = [1,1,1,1], padding = 'VALID')
    # TODO: Activation.
    conv2 = tf.nn.relu(conv2)
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    pool_2 = tf.nn.avg_pool(conv2, ksize = [1,2,2,1], strides = [1,2,2,1], padding = 'VALID') 
    
    # TODO: Flatten. Input = 5x5x16. Output = 400.
    fc1 = flatten(pool_2)
    
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_w = tf.Variable(tf.truncated_normal(shape = (400,120), mean = mu, stddev = sigma))
    fc1 = tf.matmul(fc1, fc1_w)
    # TODO: Activation.
    fc1 = tf.nn.relu(fc1)
 # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_w = tf.Variable(tf.truncated_normal(shape = (120,84), mean = mu, stddev = sigma))
    fc2 = tf.matmul(fc1, fc2_w)
    # TODO: Activation.
    fc2 = tf.nn.relu(fc2)
    # Dropout
    #fc2 = tf.nn.dropout(fc2, keep_prob)
    
    # TODO: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_w = tf.Variable(tf.truncated_normal(shape = (84,10), mean = mu , stddev = sigma))
    out = tf.matmul(fc2, fc3_w)
    return out
# Out:
# 2021-12-13 23:15:25,550 : INFO : NumExpr defaulting to 2 threads.

# %%
epochs = 50
batch_size = 128
learning_rate = 0.002
keep_probability = 0.7

# %%
logits = LeNet(x)
model = tf.identity(logits, name='logits') # Name logits Tensor, so that can be loaded from disk after training

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')
# Out:
# 2021-12-13 23:15:26,103 : WARNING : From /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2021-12-13 23:15:26,152 : WARNING : From /usr/local/lib/python3.7/dist-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# 2021-12-13 23:15:26,212 : WARNING : From <ipython-input-18-bad528e5c582>:5: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
def train_neural_network(session, optimizer, feature_batch, label_batch):
    session.run(optimizer, 
                feed_dict={
                    x: feature_batch,
                    y: label_batch,
                })

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    loss = sess.run(cost, 
                    feed_dict={
                        x: feature_batch,
                        y: label_batch,
                    })
    valid_acc = sess.run(accuracy, 
                         feed_dict={
                             x: valid_features,
                             y: valid_labels,
                         })
    
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %%
def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]

def load_preprocess_training_batch(batch_id, batch_size):
    """
    Load the Preprocessed Training data and return them in batches of <batch_size> or less
    """
    filename = data_dir + 'preprocess_batch_' + str(batch_id) + '.p'
    features, labels = pickle.load(open(filename, mode='rb'))

    # Return the training data in batches of size <batch_size> or less
    return batch_features_labels(features, labels, batch_size)

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer

def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]

def display_image_predictions(features, labels, predictions, top_n_predictions):
    n_classes = 10
    label_names = load_label_names()
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(n_classes))
    label_ids = label_binarizer.inverse_transform(np.array(labels))

    fig, axies = plt.subplots(nrows=top_n_predictions, ncols=2, figsize=(20, 10))
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions
   
    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions.indices, predictions.values)):
        if (image_i < top_n_predictions):
            pred_names = [label_names[pred_i] for pred_i in pred_indicies]
            correct_name = label_names[label_id]
            
            axies[image_i][0].imshow((feature*255).astype(np.int32, copy=False))
            axies[image_i][0].set_title(correct_name)
            axies[image_i][0].set_axis_off()
            axies[image_i][1].barh(ind + margin, pred_values[:3], width)
            axies[image_i][1].set_yticks(ind + margin)
            axies[image_i][1].set_yticklabels(pred_names[::-1])
            axies[image_i][1].set_xticks([0, 0.5, 1.0])

# %%
save_model_path = data_dir + '/image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, batch_features, batch_labels)
                
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2952 Validation Accuracy: 0.096800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.3228 Validation Accuracy: 0.096600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.3196 Validation Accuracy: 0.096600
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.2977 Validation Accuracy: 0.096200
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.2944 Validation Accuracy: 0.096400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2911 Validation Accuracy: 0.096400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.3155 Validation Accuracy: 0.097000
# Epoch  2, CIFAR-10 Batch 3:  Loss:     2.3129 Validation Accuracy: 0.097600
# Epoch  2, CIFAR-10 Batch 4:  Loss:     2.2914 Validation Accuracy: 0.098000
# Epoch  2, CIFAR-10 Batch 5:  Loss:     2.2901 Validation Accuracy: 0.099400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2863 Validation Accuracy: 0.099400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     2.3091 Validation Accuracy: 0.100400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     2.3059 Validation Accuracy: 0.101400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     2.2833 Validation Accuracy: 0.102000
# Epoch  3, CIFAR-10 Batch 5:  Loss:     2.2837 Validation Accuracy: 0.102200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.2792 Validation Accuracy: 0.108200
# Epoch  4, CIFAR-10 Batch 2:  Loss:     2.3002 Validation Accuracy: 0.112800
# Epoch  4, CIFAR-10 Batch 3:  Loss:     2.2935 Validation Accuracy: 0.116000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     2.2711 Validation Accuracy: 0.121000
# Epoch  4, CIFAR-10 Batch 5:  Loss:     2.2732 Validation Accuracy: 0.122800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2693 Validation Accuracy: 0.129000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     2.2820 Validation Accuracy: 0.136600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     2.2649 Validation Accuracy: 0.138600
# Epoch  5, CIFAR-10 Batch 4:  Loss:     2.2472 Validation Accuracy: 0.140800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     2.2518 Validation Accuracy: 0.142400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.2597 Validation Accuracy: 0.149600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     2.2487 Validation Accuracy: 0.159000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     2.2092 Validation Accuracy: 0.161400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     2.2019 Validation Accuracy: 0.161600
# Epoch  6, CIFAR-10 Batch 5:  Loss:     2.2231 Validation Accuracy: 0.164600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.2683 Validation Accuracy: 0.172600
# Epoch  7, CIFAR-10 Batch 2:  Loss:     2.2235 Validation Accuracy: 0.177600
# Epoch  7, CIFAR-10 Batch 3:  Loss:     2.1594 Validation Accuracy: 0.179600
# Epoch  7, CIFAR-10 Batch 4:  Loss:     2.1577 Validation Accuracy: 0.178600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     2.2077 Validation Accuracy: 0.178200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.2871 Validation Accuracy: 0.185000
# Epoch  8, CIFAR-10 Batch 2:  Loss:     2.2077 Validation Accuracy: 0.187400
# Epoch  8, CIFAR-10 Batch 3:  Loss:     2.1321 Validation Accuracy: 0.188200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     2.1312 Validation Accuracy: 0.187600
# Epoch  8, CIFAR-10 Batch 5:  Loss:     2.1920 Validation Accuracy: 0.186800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.2943 Validation Accuracy: 0.196000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     2.1890 Validation Accuracy: 0.199400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     2.0963 Validation Accuracy: 0.203600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     2.1041 Validation Accuracy: 0.200800
# Epoch  9, CIFAR-10 Batch 5:  Loss:     2.1663 Validation Accuracy: 0.203600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.2913 Validation Accuracy: 0.214000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     2.1671 Validation Accuracy: 0.215200
# Epoch 10, CIFAR-10 Batch 3:  Loss:     2.0352 Validation Accuracy: 0.225800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     2.0660 Validation Accuracy: 0.220200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     2.1284 Validation Accuracy: 0.223600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.2901 Validation Accuracy: 0.242400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     2.1473 Validation Accuracy: 0.244200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.9559 Validation Accuracy: 0.240800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     2.0292 Validation Accuracy: 0.253000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     2.0824 Validation Accuracy: 0.249800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.2965 Validation Accuracy: 0.264800
# Epoch 12, CIFAR-10 Batch 2:  Loss:     2.1282 Validation Accuracy: 0.266600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.8852 Validation Accuracy: 0.261200
# Epoch 12, CIFAR-10 Batch 4:  Loss:     2.0108 Validation Accuracy: 0.268000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     2.0402 Validation Accuracy: 0.272800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     2.3027 Validation Accuracy: 0.275000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     2.1179 Validation Accuracy: 0.280600
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.8387 Validation Accuracy: 0.273000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     2.0016 Validation Accuracy: 0.278600
# Epoch 13, CIFAR-10 Batch 5:  Loss:     2.0089 Validation Accuracy: 0.281800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     2.3046 Validation Accuracy: 0.285000
# Epoch 14, CIFAR-10 Batch 2:  Loss:     2.1128 Validation Accuracy: 0.285600
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.8099 Validation Accuracy: 0.283200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.9983 Validation Accuracy: 0.285400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.9865 Validation Accuracy: 0.286800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     2.3015 Validation Accuracy: 0.292600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     2.1092 Validation Accuracy: 0.292200
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.7829 Validation Accuracy: 0.292800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.9931 Validation Accuracy: 0.291600
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.9691 Validation Accuracy: 0.292400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     2.2974 Validation Accuracy: 0.294600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     2.1068 Validation Accuracy: 0.295000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.7574 Validation Accuracy: 0.297200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.9820 Validation Accuracy: 0.293400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.9547 Validation Accuracy: 0.297400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     2.2910 Validation Accuracy: 0.297800
# Epoch 17, CIFAR-10 Batch 2:  Loss:     2.1023 Validation Accuracy: 0.299000
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.7362 Validation Accuracy: 0.302600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.9647 Validation Accuracy: 0.298800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.9426 Validation Accuracy: 0.302600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     2.2795 Validation Accuracy: 0.301400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     2.0914 Validation Accuracy: 0.301600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.7156 Validation Accuracy: 0.307400
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.9495 Validation Accuracy: 0.306000
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.9348 Validation Accuracy: 0.307800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     2.2723 Validation Accuracy: 0.309200
# Epoch 19, CIFAR-10 Batch 2:  Loss:     2.0834 Validation Accuracy: 0.308000
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.6946 Validation Accuracy: 0.313200
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.9367 Validation Accuracy: 0.311800
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.9305 Validation Accuracy: 0.314000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     2.2592 Validation Accuracy: 0.313200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     2.0766 Validation Accuracy: 0.317600
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.6716 Validation Accuracy: 0.316600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.9238 Validation Accuracy: 0.317200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.9249 Validation Accuracy: 0.317000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     2.2416 Validation Accuracy: 0.317000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     2.0692 Validation Accuracy: 0.321400
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.6494 Validation Accuracy: 0.322600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.9086 Validation Accuracy: 0.322200
# Epoch 21, CIFAR-10 Batch 5:  Loss:     1.9171 Validation Accuracy: 0.321000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     2.2234 Validation Accuracy: 0.321400
# Epoch 22, CIFAR-10 Batch 2:  Loss:     2.0640 Validation Accuracy: 0.324800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.6283 Validation Accuracy: 0.324400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.8928 Validation Accuracy: 0.327200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     1.9089 Validation Accuracy: 0.331000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     2.2056 Validation Accuracy: 0.325400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     2.0581 Validation Accuracy: 0.325600
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.6086 Validation Accuracy: 0.331200
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.8799 Validation Accuracy: 0.333200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     1.9017 Validation Accuracy: 0.340000
# Epoch 24, CIFAR-10 Batch 1:  Loss:     2.1881 Validation Accuracy: 0.326800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     2.0591 Validation Accuracy: 0.329000
# Epoch 24, CIFAR-10 Batch 3:  Loss:     1.5881 Validation Accuracy: 0.333000
# Epoch 24, CIFAR-10 Batch 4:  Loss:     1.8642 Validation Accuracy: 0.338800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     1.8921 Validation Accuracy: 0.344200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     2.1653 Validation Accuracy: 0.335600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     2.0594 Validation Accuracy: 0.334400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     1.5695 Validation Accuracy: 0.334400
# Epoch 25, CIFAR-10 Batch 4:  Loss:     1.8517 Validation Accuracy: 0.342600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     1.8801 Validation Accuracy: 0.348000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     2.1437 Validation Accuracy: 0.338200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     2.0555 Validation Accuracy: 0.336400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     1.5501 Validation Accuracy: 0.336200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     1.8386 Validation Accuracy: 0.344800
# Epoch 26, CIFAR-10 Batch 5:  Loss:     1.8673 Validation Accuracy: 0.350200
# Epoch 27, CIFAR-10 Batch 1:  Loss:     2.1275 Validation Accuracy: 0.339800
# Epoch 27, CIFAR-10 Batch 2:  Loss:     2.0535 Validation Accuracy: 0.341200
# Epoch 27, CIFAR-10 Batch 3:  Loss:     1.5364 Validation Accuracy: 0.340800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     1.8266 Validation Accuracy: 0.346400
# Epoch 27, CIFAR-10 Batch 5:  Loss:     1.8572 Validation Accuracy: 0.352400
# Epoch 28, CIFAR-10 Batch 1:  Loss:     2.1089 Validation Accuracy: 0.343000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     2.0496 Validation Accuracy: 0.345000
# Epoch 28, CIFAR-10 Batch 3:  Loss:     1.5233 Validation Accuracy: 0.344800
# Epoch 28, CIFAR-10 Batch 4:  Loss:     1.8183 Validation Accuracy: 0.347800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     1.8479 Validation Accuracy: 0.354400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     2.0934 Validation Accuracy: 0.346400
# Epoch 29, CIFAR-10 Batch 2:  Loss:     2.0496 Validation Accuracy: 0.349200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     1.5097 Validation Accuracy: 0.346800
# Epoch 29, CIFAR-10 Batch 4:  Loss:     1.8070 Validation Accuracy: 0.351000
# Epoch 29, CIFAR-10 Batch 5:  Loss:     1.8365 Validation Accuracy: 0.358200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     2.0777 Validation Accuracy: 0.347000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     2.0480 Validation Accuracy: 0.352000
# Epoch 30, CIFAR-10 Batch 3:  Loss:     1.4975 Validation Accuracy: 0.348400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     1.7953 Validation Accuracy: 0.354000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     1.8237 Validation Accuracy: 0.362600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     2.0658 Validation Accuracy: 0.352200
# Epoch 31, CIFAR-10 Batch 2:  Loss:     2.0477 Validation Accuracy: 0.353000
# Epoch 31, CIFAR-10 Batch 3:  Loss:     1.4893 Validation Accuracy: 0.350800
# Epoch 31, CIFAR-10 Batch 4:  Loss:     1.7861 Validation Accuracy: 0.358800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     1.8107 Validation Accuracy: 0.367200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     2.0535 Validation Accuracy: 0.354800
# Epoch 32, CIFAR-10 Batch 2:  Loss:     2.0439 Validation Accuracy: 0.355600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     1.4778 Validation Accuracy: 0.353800
# Epoch 32, CIFAR-10 Batch 4:  Loss:     1.7762 Validation Accuracy: 0.362000
# Epoch 32, CIFAR-10 Batch 5:  Loss:     1.7995 Validation Accuracy: 0.372000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     2.0402 Validation Accuracy: 0.357800
# Epoch 33, CIFAR-10 Batch 2:  Loss:     2.0374 Validation Accuracy: 0.359200
# Epoch 33, CIFAR-10 Batch 3:  Loss:     1.4700 Validation Accuracy: 0.357000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     1.7650 Validation Accuracy: 0.365800
# Epoch 33, CIFAR-10 Batch 5:  Loss:     1.7866 Validation Accuracy: 0.375400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     2.0336 Validation Accuracy: 0.364600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     2.0296 Validation Accuracy: 0.361200
# Epoch 34, CIFAR-10 Batch 3:  Loss:     1.4614 Validation Accuracy: 0.358000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     1.7520 Validation Accuracy: 0.369000
# Epoch 34, CIFAR-10 Batch 5:  Loss:     1.7760 Validation Accuracy: 0.379200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     2.0245 Validation Accuracy: 0.368600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     2.0210 Validation Accuracy: 0.363200
# Epoch 35, CIFAR-10 Batch 3:  Loss:     1.4527 Validation Accuracy: 0.360400
# Epoch 35, CIFAR-10 Batch 4:  Loss:     1.7374 Validation Accuracy: 0.373400
# Epoch 35, CIFAR-10 Batch 5:  Loss:     1.7715 Validation Accuracy: 0.381600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     2.0126 Validation Accuracy: 0.373400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     2.0122 Validation Accuracy: 0.364600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     1.4460 Validation Accuracy: 0.362600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     1.7238 Validation Accuracy: 0.374400
# Epoch 36, CIFAR-10 Batch 5:  Loss:     1.7650 Validation Accuracy: 0.384600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     2.0054 Validation Accuracy: 0.376200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     2.0029 Validation Accuracy: 0.366400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     1.4385 Validation Accuracy: 0.365800
# Epoch 37, CIFAR-10 Batch 4:  Loss:     1.7109 Validation Accuracy: 0.376600
# Epoch 37, CIFAR-10 Batch 5:  Loss:     1.7560 Validation Accuracy: 0.386000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.9922 Validation Accuracy: 0.378800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     1.9938 Validation Accuracy: 0.365600
# Epoch 38, CIFAR-10 Batch 3:  Loss:     1.4318 Validation Accuracy: 0.367200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     1.6952 Validation Accuracy: 0.381200
# Epoch 38, CIFAR-10 Batch 5:  Loss:     1.7482 Validation Accuracy: 0.389200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.9844 Validation Accuracy: 0.378200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     1.9834 Validation Accuracy: 0.366800
# Epoch 39, CIFAR-10 Batch 3:  Loss:     1.4246 Validation Accuracy: 0.368800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     1.6819 Validation Accuracy: 0.386200
# Epoch 39, CIFAR-10 Batch 5:  Loss:     1.7434 Validation Accuracy: 0.389400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.9770 Validation Accuracy: 0.381600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     1.9693 Validation Accuracy: 0.367200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     1.4188 Validation Accuracy: 0.370600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     1.6687 Validation Accuracy: 0.388000
# Epoch 40, CIFAR-10 Batch 5:  Loss:     1.7375 Validation Accuracy: 0.392400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.9699 Validation Accuracy: 0.384600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     1.9531 Validation Accuracy: 0.368000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     1.4123 Validation Accuracy: 0.371200
# Epoch 41, CIFAR-10 Batch 4:  Loss:     1.6542 Validation Accuracy: 0.391800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     1.7312 Validation Accuracy: 0.395600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.9578 Validation Accuracy: 0.388600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     1.9373 Validation Accuracy: 0.367800
# Epoch 42, CIFAR-10 Batch 3:  Loss:     1.4044 Validation Accuracy: 0.375400
# Epoch 42, CIFAR-10 Batch 4:  Loss:     1.6424 Validation Accuracy: 0.392600
# Epoch 42, CIFAR-10 Batch 5:  Loss:     1.7236 Validation Accuracy: 0.398600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.9489 Validation Accuracy: 0.389000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     1.9259 Validation Accuracy: 0.367200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     1.3985 Validation Accuracy: 0.376000
# Epoch 43, CIFAR-10 Batch 4:  Loss:     1.6308 Validation Accuracy: 0.395400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     1.7184 Validation Accuracy: 0.400800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.9409 Validation Accuracy: 0.394400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     1.9175 Validation Accuracy: 0.370400
# Epoch 44, CIFAR-10 Batch 3:  Loss:     1.3917 Validation Accuracy: 0.377600
# Epoch 44, CIFAR-10 Batch 4:  Loss:     1.6197 Validation Accuracy: 0.397400
# Epoch 44, CIFAR-10 Batch 5:  Loss:     1.7136 Validation Accuracy: 0.402600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.9356 Validation Accuracy: 0.397600
# Epoch 45, CIFAR-10 Batch 2:  Loss:     1.9056 Validation Accuracy: 0.370000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     1.3824 Validation Accuracy: 0.381600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     1.6102 Validation Accuracy: 0.399800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     1.7102 Validation Accuracy: 0.405200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.9272 Validation Accuracy: 0.401600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     1.8917 Validation Accuracy: 0.374800
# Epoch 46, CIFAR-10 Batch 3:  Loss:     1.3734 Validation Accuracy: 0.382600
# Epoch 46, CIFAR-10 Batch 4:  Loss:     1.6003 Validation Accuracy: 0.398600
# Epoch 46, CIFAR-10 Batch 5:  Loss:     1.7071 Validation Accuracy: 0.407000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.9280 Validation Accuracy: 0.402400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     1.8773 Validation Accuracy: 0.377200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     1.3639 Validation Accuracy: 0.384200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     1.5872 Validation Accuracy: 0.399000
# Epoch 47, CIFAR-10 Batch 5:  Loss:     1.7025 Validation Accuracy: 0.409200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     1.9191 Validation Accuracy: 0.402000
# Epoch 48, CIFAR-10 Batch 2:  Loss:     1.8686 Validation Accuracy: 0.379600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     1.3569 Validation Accuracy: 0.387200
# Epoch 48, CIFAR-10 Batch 4:  Loss:     1.5747 Validation Accuracy: 0.398200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     1.6963 Validation Accuracy: 0.410400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     1.9114 Validation Accuracy: 0.404800
# Epoch 49, CIFAR-10 Batch 2:  Loss:     1.8541 Validation Accuracy: 0.382200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     1.3495 Validation Accuracy: 0.389600
# Epoch 49, CIFAR-10 Batch 4:  Loss:     1.5642 Validation Accuracy: 0.401800
# Epoch 49, CIFAR-10 Batch 5:  Loss:     1.6914 Validation Accuracy: 0.411600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     1.9010 Validation Accuracy: 0.407800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     1.8423 Validation Accuracy: 0.383600
# Epoch 50, CIFAR-10 Batch 3:  Loss:     1.3434 Validation Accuracy: 0.392200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     1.5552 Validation Accuracy: 0.403800
# Epoch 50, CIFAR-10 Batch 5:  Loss:     1.6855 Validation Accuracy: 0.417000

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer

def batch_features_labels(features, labels, batch_size):
    """
    Split features and labels into batches
    """
    for start in range(0, len(features), batch_size):
        end = min(start + batch_size, len(features))
        yield features[start:end], labels[start:end]

def display_image_predictions(features, labels, predictions, top_n_predictions):
    n_classes = 10
    label_names = load_label_names()
    label_binarizer = LabelBinarizer()
    label_binarizer.fit(range(n_classes))
    label_ids = label_binarizer.inverse_transform(np.array(labels))

    fig, axies = plt.subplots(nrows=top_n_predictions, ncols=2, figsize=(20, 10))
    fig.tight_layout()
    fig.suptitle('Softmax Predictions', fontsize=20, y=1.1)

    n_predictions = 3
    margin = 0.05
    ind = np.arange(n_predictions)
    width = (1. - 2. * margin) / n_predictions
   
    for image_i, (feature, label_id, pred_indicies, pred_values) in enumerate(zip(features, label_ids, predictions.indices, predictions.values)):
        if (image_i < top_n_predictions):
            pred_names = [label_names[pred_i] for pred_i in pred_indicies]
            correct_name = label_names[label_id]
            axies[image_i][0].imshow((feature*255).astype(np.int32, copy=False))
            axies[image_i][0].set_title(correct_name)
            axies[image_i][0].set_axis_off()

            axies[image_i][1].barh(ind + margin, pred_values[:3], width)
            axies[image_i][1].set_yticks(ind + margin)
            axies[image_i][1].set_yticklabels(pred_names[::-1])
            axies[image_i][1].set_xticks([0, 0.5, 1.0])

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import random

save_model_path = data_dir + 'image_classification'
batch_size = 64
n_samples = 500
top_n_predictions = 10

def test_model():
    test_features, test_labels = pickle.load(open(data_dir + 'preprocess_testing.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('input_x:0')
        loaded_y = loaded_graph.get_tensor_by_name('output_y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels})
        display_image_predictions(random_test_features, random_test_labels, random_test_predictions, top_n_predictions)


test_model()
# Out:
# 2021-12-14 00:13:08,057 : WARNING : From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2021-12-14 00:13:08,065 : INFO : Restoring parameters from drive/My Drive/Colab Notebooks/cnn_cifar10/image_classification
# Testing Accuracy: 0.41321656050955413
